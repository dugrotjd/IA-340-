# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia-340-2025-fall-kncxmxnzk2484/CSRIC_Best_Practices.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#     BP Number Priority                                        Description  \
# 0  11-10-5064      NaN  "Retired" - Network Operators, Service Provide...
# 1  11-10-5164      NaN  "Retired" - Network Operators, Service Provide...
# 2  11-11-3249      NaN  "Retired" - Public Safety should  in regards t...
# 3   11-7-8548      NaN  "Retired" - Network Operators and Service Prov...
# 4   11-8-8051      NaN  "Retired" - Network Operators should ensure th...
#
#                                      Network Type(s)  \
# 0  Cable; Internet/Data; Satellite; Wireless; Wir...
# 1  Cable; Internet/Data; Satellite; Wireless; Wir...
# 2  Cable; Internet/Data; Satellite; Wireless; Wir...
# 3  Cable; Internet/Data; Satellite; Wireless; Wir...
# 4                                          Wireline;
#
#                                     Industry Role(s)  \
# 0  Service Provider; Network Operator; Public Saf...
# 1  Service Provider; Network Operator; Equipment ...
# ...

# %%
df.shape
# Out:
# (1129, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129 entries, 0 to 1128
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BP Number                   1127 non-null   object
#  1   Priority                    1006 non-null   object
#  2   Description                 1129 non-null   object
#  3   Network Type(s)             1129 non-null   object
#  4   Industry Role(s)            1129 non-null   object
#  5   Keywords                    1125 non-null   object
#  6   Public Safety and Disaster  1129 non-null   bool
#  7   Reference                   492 non-null    object
#  8   cable                       1129 non-null   bool
#  9   internet/Data               1129 non-null   bool
#  10  satellite                   1129 non-null   bool
#  11  wireless                    1129 non-null   bool
#  12  wireline                    1129 non-null   bool
# ...

# %%
df.head() My data highlights terrorist attacks aouns the world and I have 20 columns of information and then i have four rows. Initially i noticed that this data is nonnumerical and exclusivly is based on a qualitative data set
# Out:
#     BP Number Priority                                        Description  \
# 0  11-10-5064      NaN  "Retired" - Network Operators, Service Provide...
# 1  11-10-5164      NaN  "Retired" - Network Operators, Service Provide...
# 2  11-11-3249      NaN  "Retired" - Public Safety should  in regards t...
# 3   11-7-8548      NaN  "Retired" - Network Operators and Service Prov...
# 4   11-8-8051      NaN  "Retired" - Network Operators should ensure th...
#
#                                      Network Type(s)  \
# 0  Cable; Internet/Data; Satellite; Wireless; Wir...
# 1  Cable; Internet/Data; Satellite; Wireless; Wir...
# 2  Cable; Internet/Data; Satellite; Wireless; Wir...
# 3  Cable; Internet/Data; Satellite; Wireless; Wir...
# 4                                          Wireline;
#
#                                     Industry Role(s)  \
# 0  Service Provider; Network Operator; Public Saf...
# 1  Service Provider; Network Operator; Equipment ...
# ...

# %%
df.describe()
# Out:
#        Priority (1,2,3)
# count       1006.000000
# mean           1.727634
# std            0.760578
# min            1.000000
# 25%            1.000000
# 50%            2.000000
# 75%            2.000000
# max            3.000000

# %%
df = df.rename(columns={"BP Number": "BP#", "Priority": "Important","Network Type(s)":"NWT" }) I renamed BP munber to BP#, Priority to important, and Netwrk ype(s) to NWT, I put in the code to drop my missing values and I didnt have any missing values 
df.head()
# Out:
#           BP# Important                                        Description  \
# 0  11-10-5064       NaN  "Retired" - Network Operators, Service Provide...
# 1  11-10-5164       NaN  "Retired" - Network Operators, Service Provide...
# 2  11-11-3249       NaN  "Retired" - Public Safety should  in regards t...
# 3   11-7-8548       NaN  "Retired" - Network Operators and Service Prov...
# 4   11-8-8051       NaN  "Retired" - Network Operators should ensure th...
#
#                                                  NWT  \
# 0  Cable; Internet/Data; Satellite; Wireless; Wir...
# 1  Cable; Internet/Data; Satellite; Wireless; Wir...
# 2  Cable; Internet/Data; Satellite; Wireless; Wir...
# 3  Cable; Internet/Data; Satellite; Wireless; Wir...
# 4                                          Wireline;
#
#                                     Industry Role(s)  \
# 0  Service Provider; Network Operator; Public Saf...
# 1  Service Provider; Network Operator; Equipment ...
# ...

# %%
df.isnull().sum() #I dropped the rows that comtained null values
# Out:
# BP#                           0
# Important                     0
# Description                   0
# NWT                           0
# Industry Role(s)              0
# Keywords                      0
# Public Safety and Disaster    0
# Reference                     0
# cable                         0
# internet/Data                 0
# satellite                     0
# wireless                      0
# wireline                      0
# Service Provider              0
# Network Operator              0
# Priority (1,2,3)              0
# Equipment Supplier            0
# Property Manager              0
# Government                    0
# Public Safety                 0
# dtype: int64

# %%
df = df.dropna() #drop null values
df.isnull().sum()
# Out:
# BP#                           0
# Important                     0
# Description                   0
# NWT                           0
# Industry Role(s)              0
# Keywords                      0
# Public Safety and Disaster    0
# Reference                     0
# cable                         0
# internet/Data                 0
# satellite                     0
# wireless                      0
# wireline                      0
# Service Provider              0
# Network Operator              0
# Priority (1,2,3)              0
# Equipment Supplier            0
# Property Manager              0
# Government                    0
# Public Safety                 0
# dtype: int64

# %%
df['BP#' ]
# Out:
# 13      13-10-0418
# 16      13-10-0421
# 17      13-10-0424
# 19      13-10-0429
# 21      13-10-0431
#            ...
# 1065     13-9-8759
# 1066     13-9-8762
# 1089    13-13-8118
# 1090    13-13-8527
# 1093    13-13-8768
# Name: BP#, Length: 470, dtype: object

# %%
df.sort_values(by='BP#')
# Out:
#              BP#         Important  \
# 13    13-10-0418  Highly Important
# 16    13-10-0421  Highly Important
# 17    13-10-0424         Important
# 19    13-10-0429  Highly Important
# 21    13-10-0431  Highly Important
# ...          ...               ...
# 1062   13-9-8755         Important
# 1063   13-9-8756          Critical
# 1064   13-9-8757         Important
# 1065   13-9-8759  Highly Important
# 1066   13-9-8762          Critical
#
#                                             Description  \
# 13    Network Operators, Service Providers and Publi...
# 16    Equipment Suppliers should design network elem...
# 17    Network Operators and Public Safety should whe...
# 19    Equipment Suppliers should provide for appropr...
# 21    Equipment Suppliers should provide capacity an...
# ...                                                 ...
# 1062  Service Providers, Network Operators, Equipmen...
# 1063  Network Operators and Public Safety should est...
# ...

# %%
df[0:5]
# Out:
#            BP#         Important  \
# 13  13-10-0418  Highly Important
# 16  13-10-0421  Highly Important
# 17  13-10-0424         Important
# 19  13-10-0429  Highly Important
# 21  13-10-0431  Highly Important
#
#                                           Description  \
# 13  Network Operators, Service Providers and Publi...
# 16  Equipment Suppliers should design network elem...
# 17  Network Operators and Public Safety should whe...
# 19  Equipment Suppliers should provide for appropr...
# 21  Equipment Suppliers should provide capacity an...
#
#                                                   NWT  \
# 13  Cable; Internet/Data; Satellite; Wireless; Wir...
# 16  Cable; Internet/Data; Satellite; Wireless; Wir...
# 17  Cable; Internet/Data; Satellite; Wireless; Wir...
# 19  Cable; Internet/Data; Satellite; Wireless; Wir...
# 21  Cable; Internet/Data; Satellite; Wireless; Wir...
#
#                                      Industry Role(s)  \
# ...

# %%
df[df['Priority (1,2,3)'] > 1.0 ]
# Out:
#              BP#         Important  \
# 13    13-10-0418  Highly Important
# 16    13-10-0421  Highly Important
# 19    13-10-0429  Highly Important
# 21    13-10-0431  Highly Important
# 22    13-10-0432  Highly Important
# ...          ...               ...
# 1065   13-9-8759  Highly Important
# 1066   13-9-8762          Critical
# 1089  13-13-8118          Critical
# 1090  13-13-8527          Critical
# 1093  13-13-8768  Highly Important
#
#                                             Description  \
# 13    Network Operators, Service Providers and Publi...
# 16    Equipment Suppliers should design network elem...
# 19    Equipment Suppliers should provide for appropr...
# 21    Equipment Suppliers should provide capacity an...
# 22    Equipment Suppliers should support standardize...
# ...                                                 ...
# 1065  Network Operators and Service Providers should...
# 1066  Network Operators and Service Providers should...
# ...

# %% [markdown]
# I selected to show my BP# column and sort it as well. The output shows the information in my BP# however I am unsure what the output means in its entirety
